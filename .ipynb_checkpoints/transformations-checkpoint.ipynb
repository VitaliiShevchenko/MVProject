# %% [markdown]
# # INSTALL DEPENDENCIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
colorImg = cv2.imread(r'../../Downloads/download.png')
grayImgBGR = cv2.imread(r'../../Downloads/puppy.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(grayImgBGR, cmap='gray')

# %%
plt.imshow(colorImg[:,:,::-1])

# %%
gray_resised_img = cv2.resize(src=grayImg, fx=2, fy=0.5, dsize=None)

# %%
plt.imshow(gray_resised_img, cmap="gray")
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
color_resized_img = cv2.resize(src=colorImg, fx=2, fy=.5, dsize=None)
plt.imshow(color_resized_img[:,:,::-1])
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])
